# %%
i = 0
temp = 200

while i < 20000:
    temp = 200 * pow(0.01 / 200,(i/20000))
    print(temp)
    i += 1
# Out:
# 200.0
# 199.90098964019438
# 199.8020282956455
# 199.70311594208826
# 199.60425255526962
# 199.50543811094846
# 199.40667258489577
# 199.30795595289442
# 199.2092881907393
# 199.11066927423738
# 199.01209917920747
# 198.91357788148045
# 198.8151053568991
# 198.7166815813182
# 198.61830653060449
# 198.5199801806366
# 198.42170250730516
# 198.32347348651268
# 198.22529309417368
# 198.12716130621453
# 198.02907809857356
# 197.93104344720098
# 197.83305732805894
# 197.73511971712145
# 197.63723059037446
# 197.53938992381578
# 197.44159769345507
# 197.34385387531393
# 197.2461584454258
# 197.148511379836
# 197.05091265460172
# 196.95336224579194
# 196.85586012948752
# 196.7584062817812
# 196.6610006787775
# 196.5636432965928
# 196.4663341113553
# 196.36907309920502
# 196.27186023629378
# 196.1746954987852
# 196.07757886285472
# 195.9805103046896
# 195.88348980048883
# 195.78651732646318
# 195.68959285883528
# 195.59271637383944
# 195.49588784772175
# 195.39910725674014
# ...

# %%
roster1, roster2= 0,0
[a,b] = [roster1, roster2]

print(roster1,roster2)
# Out:
# 0 0

# %%
activities = ["spelen", "lopen", "rennen"]
              
print(activities[len(activities)-1])
# Out:
# rennen
